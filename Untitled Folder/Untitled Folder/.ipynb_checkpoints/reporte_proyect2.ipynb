# %% [markdown]
# # **Proyecto 2**
# ### *Edward Smalley Tohom Hernández*
# ### ***23006412, Sección V, Universidad Galileo***
# ### *edwardtohom@galileo.com*

# %% [markdown]
# _______________________________________________________________________________________________________________

# %% [markdown]
# ##### **Scope**: El departamento de recursos humanos desea llevar el control interno de los empleados de la empresa Industrial en Madrid, España. El departamento de recursos humanos desea conocer información general de los empleados, como sus información básica y salarios. También desean llevar el control de los diferentes departamentos de la empresa, como, por ejemplo, departamento de finanzas, organización y personal.  Algo que es importante para recursos humanos es conocer que empleados trabajan directamente con los clientes y que empleados trabajan en el área operativa. Para ello se requiere, desarrollar un pipeline de ingeniería utilizando Python, Postgres y AWS como herramientas de desarrollo.

# %% [markdown]
# ##### **Exploración de los datos**: La empresa industrial brindo el siguiente modelo de exploración de los datos:
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Modelo de datos**: La empresa industrial brindo el siguiente modelo de exploración de los datos:
# ![image.png](attachment:image.png)
#
# Para ello, se utilizo el modelo data warehouse -DW
#
# ![image.png](attachment:image-3.png)
#
# Tambien se cargo la base de datos a Postgres y AWS
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image-4.png)

# %% [markdown]
# ##### **Procesamiento de datos:** Para la ingeniería de datos se utilizó las plataformas de Python para la creación de scripts, AWS y PostgreSQL para la creación de la base de datos con servicio en la nube y su almacenamiento. También se utilizo el servicio de Amazon S3 que proporciona almacenamiento de objetos a través de una interfaz de servicio web.
#
# ##### A continuación, se describe el detallado de los scripts:
#
# •	**Proyecto2.ipynb:**
#
# o	Creación de la base de datos desde Python
#
# o	Creación de instancia de RDS en AWS.
#
# o	Conexión de base de base de datos desde Python y Postgres
#
# o	Creación de tablas transacciones y de hechos
#
# o	Inserción de datos a las tablas
#
# •	**Dw_p2.ipynb**
#
# o	Lectura de datos desde Python a Postgres utilizando DBeaver
#
# o	Utilización de sintaxis SQL desde Python para corroborar los datos y contestar a las preguntas de análisis
#
# •	**Dw_s3_p2.ipynb**
#
# o	Desde AWS se cargo el archivo de S3 "llamado conversión_euro_dolar” para convertir los salarios de euros a dólares a solicitud de recursos humanos
#
# o	Desde Python se realizaron las configuraciones necesarias para leer los datos S3 de AWS
#
# •	**Reporte_proyecto2.ipynb**
#
# o	Scope del proyecto
#
# o	Exploración de datos
#
# o	Modelo de datos
#
# o	Procesamiento de datos
#
# o	Analítica
#
# o	Reporte del proyecto
#
# •	**escec.cfg**
#
# o	Configuración de IAM, RDS y VPC entre Python y AWS
#
# •	**sql_queries.py**
#
# o	Script SQL para crear las tablas de la base de datos

# %% [markdown]
# #### **Analítica:** La empresa industrial desea conocer las respuestas a las siguientes preguntas:
#
# **1.	¿Cuál es la información básica de los empleados que laboran en la empresa industrial de Madrid, España?**
# ![image.png](attachment:image.png)
#
#
# **2.	¿Cuáles son los departamentos que existen dentro de la empresa industrial?**
# ![image.png](attachment:image-2.png)
#
#
# **3.	¿Qué empleados brindan servicio al cliente y quienes laboran en la parte operativa o sede central de la empresa?**
# ![image.png](attachment:image-3.png)
#
#
# **4.	Listado de salarios (en dolares) de los empleados de la empresa industrial**
# ![image.png](attachment:image-4.png)
#
#
# **5.	¿Qué departamento tiene mayor presupuesto?**
#
# ![image.png](attachment:image-5.png)
